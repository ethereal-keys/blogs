# %%
import cv2
import numpy as np

filename = 'lay.jpg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2.imshow('dst',img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the resulting frame
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-db48bc6d3aa5> in <module>()
#       6 while(True):
#       7     # Capture frame-by-frame
# ----> 8     ret, frame = cap.read()
#       9
#      10     # Our operations on the frame come here
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('lay.jpg',0)
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('lay2.jpg',0)
img = cv2.medianBlur(img,5)

ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,3)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
cv2.imwrite('binarized.jpg',th3);

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('binarized.png',0)
# global thresholding
ret1,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv.threshold(img,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv.GaussianBlur(img,(5,5),0)
ret3,th3 = cv.threshold(blur,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
cv2.imwrite('noise.jpg',th3)
# Out:
# False

# %%
import cv2  
  
# path  
path = r'C:\Users\sikan\Documents\hashcode\layout.jpeg'
  
# Reading an image in default mode 
image = cv2.imread(path) 
  
# Window name in which image is displayed 
window_name = 'image'
  
# Using cv2.imshow() method  
# Displaying the image  
cv2.imshow(window_name, image)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\users\sikan\appdata\local\programs\python\python36\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "c:\users\sikan\appdata\local\programs\python\python36\lib\asyncio\selector_events.py", line 141, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\users\sikan\appdata\local\programs\python\python36\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "c:\users\sikan\appdata\local\programs\python\python36\lib\asyncio\selector_events.py", line 141, in _read_from_self
# ...

# %%
import cv2
import numpy

# Load the image
img = cv2.imread("https://i.stack.imgur.com/i7g0M.png")

# Split out each channel
blue, green, red = cv2.split(img)

def medianCanny(img, thresh1, thresh2):
    median = numpy.median(img)
    img = cv2.Canny(img, int(thresh1 * median), int(thresh2 * median))
    return img

# Run canny edge detection on each channel
blue_edges = medianCanny(blue, 0.2, 0.3)
green_edges = medianCanny(green, 0.2, 0.3)
red_edges = medianCanny(red, 0.2, 0.3)

# Join edges back into image
edges = blue_edges | green_edges | red_edges

# Find the contours
contours,hierarchy = cv2.findContours(edges, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

hierarchy = hierarchy[0] # get the actual inner list of hierarchy descriptions

# For each contour, find the bounding rectangle and draw it
for component in zip(contours, hierarchy):
    currentContour = component[0]
    currentHierarchy = component[1]
    x,y,w,h = cv2.boundingRect(currentContour)
    if currentHierarchy[2] < 0:
        # these are the innermost child components
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),3)
    elif currentHierarchy[3] < 0:
        # these are the outermost parent components
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),3)

# Finally show the image
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-85bc7cf4a378> in <module>()
#       6
#       7 # Split out each channel
# ----> 8 blue, green, red = cv2.split(img)
#       9
#      10 def medianCanny(img, thresh1, thresh2):
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
import cv2
img = cv2.imread("https://i.stack.imgur.com/i7g0M.png")
image = cv2.split(img)
def medianCanny(img, thresh1, thresh2):
    median = numpy.median(img)
    img = cv2.Canny(img, int(thresh1 * median), int(thresh2 * median))
    return img
contours,hierarchy = cv2.findContours(red, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f48e859b1982> in <module>()
#       2 img = cv2.imread("https://i.stack.imgur.com/i7g0M.png")
#       3 red = cv2.split(img)
# ----> 4 contours,hierarchy = cv2.findContours(red, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
#
# TypeError: image is not a numpy array, neither a scalar

# %%
import cv2
import numpy

# Load the image
img = cv2.imread("erode.jpg")

# Split out each channel
blue, green, red = cv2.split(img)

def medianCanny(img, thresh1, thresh2):
    median = numpy.median(img)
    img = cv2.Canny(img, int(thresh1 * median), int(thresh2 * median))
    return img

# Run canny edge detection on each channel
blue_edges = medianCanny(blue, 0.2, 0.3)
green_edges = medianCanny(green, 0.2, 0.3)
red_edges = medianCanny(red, 0.2, 0.3)

# Join edges back into image
edges = blue_edges | green_edges | red_edges

# Find the contours
cimg,contour,heirarchy = cv2.findContours(edges, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cv2.imwrite('contr.jpg',cimg)
print(len(contour))
print(len(heirarchy))
print(heirarchy)
tree=[]
leaf=[]
parent=[]
child=[]
visited=[]
for i in range(len(heirarchy[0])):
    visited.append(0)
for i in heirarchy[0]:
    if i[0]==-1 and i[1]==-1 and i[2]==-1 :
        leaf.append(i)
    parent.append(i[3]);
    child.append(i[2]);
for i in leaf:
    t=parent.index(i[3])
    visited[t]=1
    while(heirarchy[0][t][3]!=-1 and visited[t]!=1):
        t=parent.index(heirarchy[0][t][3])

img = cv2.drawContours(img,contour,-1,[0,255,0],3)
cv2.imwrite('contr2.jpg',img)    


cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 60
# 1
# [[[ 2 -1  1 -1]
#   [-1 -1 -1  0]
#   [ 4  0  3 -1]
#   [-1 -1 -1  2]
#   [-1  2  5 -1]
#   [-1 -1  6  4]
#   [-1 -1  7  5]
#   [-1 -1  8  6]
#   [20 -1  9  7]
#   [-1 -1 10  8]
#   [-1 -1 11  9]
#   [-1 -1 12 10]
#   [16 -1 13 11]
#   [-1 -1 14 12]
#   [-1 -1 15 13]
#   [-1 -1 -1 14]
#   [-1 12 17 11]
#   [-1 -1 18 16]
#   [-1 -1 19 17]
#   [-1 -1 -1 18]
#   [32  8 21  7]
#   [-1 -1 22 20]
#   [-1 -1 23 21]
#   [-1 -1 24 22]
#   [28 -1 25 23]
#   [-1 -1 26 24]
#   [-1 -1 27 25]
#   [-1 -1 -1 26]
#   [-1 24 29 23]
#   [-1 -1 30 28]
#   [-1 -1 31 29]
#   [-1 -1 -1 30]
#   [36 20 33  7]
#   [-1 -1 34 32]
#   [-1 -1 35 33]
#   [-1 -1 -1 34]
#   [52 32 37  7]
#   [-1 -1 38 36]
#   [-1 -1 39 37]
#   [-1 -1 40 38]
#   [44 -1 41 39]
#   [-1 -1 42 40]
#   [-1 -1 43 41]
#   [-1 -1 -1 42]
#   [48 40 45 39]
#   [-1 -1 46 44]
#   [-1 -1 47 45]
#   [-1 -1 -1 46]
#   [-1 44 49 39]
#   [-1 -1 50 48]
#   [-1 -1 51 49]
#   [-1 -1 -1 50]
#   [56 36 53  7]
#   [-1 -1 54 52]
#   [-1 -1 55 53]
# ...

# %%
import cv2 as cv
import numpy as np
img = cv.imread('binarized.png',0)
kernel = np.ones((5,5), np.uint32)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
cv.imshow('jhd', img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e18ec7b57163> in <module>()
#       3 img = cv.imread('binarized.png',0)
#       4 kernel = np.ones((5,5), np.uint32)
# ----> 5 opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
#       6 cv.imshow('jhd', img)
#
# TypeError: kernel data type = 8 is not supported

# %%
import cv2
import numpy as np

img = cv2.imread('binarized.jpg',0)
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 2)
cv2.imwrite('erode.jpg',erosion)
# Out:
# True

# %%
import cv2
import numpy as np

img = cv2.imread('binarized.jpg',0)
kernel = np.ones((5,5),np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
cv2.imwrite('erode.jpg',erosion)

# %%
import cv2
import numpy
import json
#contour traversal
def rec_tree(node):
    fchild=node[2]
    tr={}
    if fchild==-1:
        tr[node]={}
        return tr
    while(heirarchy[0][fchild][2]!=-1):
        l=list(heirarchy[0][fchild])
        m=[]
        for i in heirarchy[0]:
            m.append(list(i))
        l.append(m.index(l))
        tr[tuple(l)]={}
        fchild=heirarchy[0][fchild][0]
    for i in tr.keys():
        tr[i]=rec_tree(tuple(i,))
    return tr



#    <h5 class="card-title">Card title</h5>
#    <p class="card-text">Some quick example text to build on the card title and make up the bulk of the card's content.</p>
   


def dom_tree(node):
    s=""
    if len(node.keys()) == 0:
        return "<p>text here</p>"
    else:
        for i in node.keys():
            s=s+"\n<div>\n"+dom_tree(node[i])+"\n</div>\n"
        return s
    
def box_bdr(node,bbimg):
    if len(node.keys()) == 0:
        return bbimg
    else:
        for i in node.keys():
            left,top,wdth,hgt = cv2.boundingRect(contour[i[4]])
            bbimg=cv2.rectangle(bbimg,(left,top),(left+wdth,top+hgt),(0,255,0),2)
            bbimg=box_bdr(node[i],bbimg)
        return bbimg
            
#removing duplicate contours

# def dup_tree(node):
#     fchild=node[2]
#     tr={}
#     ts={}
#     if fchild==-1:
#         tr[node]={}
#         ts[str(node)]={}
#         return ts
#     while(heirarchy[0][fchild][2]!=-1):
#         tr[tuple(heirarchy[0][fchild])]={}
#         ts[str(tuple(heirarchy[0][fchild]))]={}
#         fchild=heirarchy[0][fchild][0]
#     for i in ts.keys():
#         ts[i]=rec_tree(tuple(i,))
#     return ts
def dup_tree(node):        
    if len(node.keys()) == 0:
        return {}
    elif len(node.keys()) == 1:
        for i in node.keys():
            return dup_tree(node[i])
    else:
        for i in node.keys():
            node[i]=dup_tree(node[i])
        return node

# Load the image

blk=cv2.imread('blank.png')
img = cv2.imread("erode.jpg")

# Split out each channel
blue, green, red = cv2.split(img)

def medianCanny(img, thresh1, thresh2):
    median = numpy.median(img)
    img = cv2.Canny(img, int(thresh1 * median), int(thresh2 * median))
    return img

# Run canny edge detection on each channel
blue_edges = medianCanny(blue, 0.2, 0.3)
green_edges = medianCanny(green, 0.2, 0.3)
red_edges = medianCanny(red, 0.2, 0.3)

# Join edges back into image
edges = blue_edges | green_edges | red_edges

# Find the contours
cimg,contour,heirarchy = cv2.findContours(edges, cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
cv2.imwrite('contr.jpg',cimg)
#print(len(contour))
#print(len(heirarchy))
#print(heirarchy)
tree={}
stree={}
root=[]
leaf=[]
parent=[]
child=[]
visited=[]
rindx=[]
kl=0
for i in range(len(heirarchy[0])):
    visited.append(0)
for i in heirarchy[0]:
    if i[0]==-1 and i[1]==-1 and i[2]==-1 :
        leaf.append(i)
    if i[3]==-1:
        root.append(list(i))
        rindx.append(kl)
    kl+=1
    parent.append(i[3]);
    child.append(i[2]);
frindx=[]
kl=-1
for i in root:
    #make key from root elements
    if i[3]==-1 and heirarchy[0][i[2]][2]==-1:
        kl+=1
        continue
    kl+=1
    frindx.append(rindx[kl])
    tree[tuple(i)]=rec_tree(tuple(i,))
#jtree=json.dumps(tree)
# for i in root:
#     #make key from root elements
#     if i[3]==-1 and heirarchy[0][i[2]][2]==-1:
#         continue
#     stree[str(tuple(i))]=dup_tree(tuple(i,))


stree=dup_tree(tree)
print(stree)
print(frindx)
# sdom='''<!-- Latest compiled and minified CSS -->
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">

# <!-- Optional theme -->
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap-theme.min.css" integrity="sha384-rHyoN1iRsVXV4nD0JutlnGaslCJuC7uwjduW9SVrLvRYooPp2bWYgmgJQIXwl/Sp" crossorigin="anonymous">

# <!-- Latest compiled and minified JavaScript -->
# <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script>'''
sdom=dom_tree(stree)
left,top,wdth,hgt = cv2.boundingRect(contour[frindx[0]])
blk=cv2.rectangle(blk,(left,top),(left+wdth,top+hgt),(0,255,0),2)
#print(sdom)
#print(tree)
file1 = open("gjs-hw/domt.txt","w")
file1.write(sdom)
file1.close()
greenbox=box_bdr(stree,blk)
cv2.imwrite('dst.jpg',greenbox)
# Out:
# {(19, -1, 9, 7, 8): {(14, -1, 11, 9, 10): {}, (18, 10, 15, 9, 14): {}}, (31, 8, 20, 7, 19): {(27, -1, 24, 22, 23): {}, (-1, 23, 28, 22, 27): {}}, (35, 19, 32, 7, 31): {}, (51, 31, 36, 7, 35): {(43, -1, 40, 38, 39): {}, (47, 39, 44, 38, 43): {}, (-1, 43, 48, 38, 47): {}}, (55, 35, 52, 7, 51): {}, (-1, 51, 56, 7, 55): {}}
# [4]
# True

# %%
import cv2
import numpy as np# Reading in and displaying our image
image = cv2.imread('lay6.png')
#cv2.imshow('Original', image)# Create our shapening kernel, it must equal to one eventually
kernel_sharpening = np.array([[-1,-1,-1], 
                              [-1, 9,-1],
                              [-1,-1,-1]])# applying the sharpening kernel to the input image & displaying it.
sharpened = cv2.filter2D(image, -1, kernel_sharpening)
#cv2.imshow('Image Sharpening', sharpened)
cv2.imwrite('sharp.jpg',sharpened)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
cv2.videoCapture()
